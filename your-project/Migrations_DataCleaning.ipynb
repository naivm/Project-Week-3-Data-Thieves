# %%
# import libraries
import pandas as pd
import numpy as np

# %%
#import csv file and create data frame
migrations = pd.read_csv('UN_MigrantStockByOriginAndDestination_2017.csv',low_memory=False)
migrations.head(50)
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# 5         NaN                                                NaN
# 6         NaN                                                NaN
# 7         NaN                                                NaN
# 8         NaN                                                NaN
# 9         NaN                                                NaN
# 10        NaN                                                NaN
# 11        NaN  Suggested citation: United Nations, Department...
# 12        NaN                                                NaN
# ...

# %%
type(migrations)
# Out:
# pandas.core.frame.DataFrame

# %%
#migrations.describe()

# %%
#migrations.shape

# %%
#check for NaN values 
migrations.isnull().sum()
migra_null = migrations.isnull().sum()
migra_null [migra_null > 0]
# Out:
# Unnamed: 0          41
# Unnamed: 1          40
# Unnamed: 2          41
# Unnamed: 3        1693
# Unnamed: 4          35
# Unnamed: 5         307
# Unnamed: 6          40
# Unnamed: 7          41
# Unnamed: 8          41
# Unnamed: 9          41
# Unnamed: 10         41
# Unnamed: 11         41
# Unnamed: 12         41
# Unnamed: 13         41
# Unnamed: 14         41
# Unnamed: 15         41
# Unnamed: 16         41
# Unnamed: 17         41
# Unnamed: 18         41
# Unnamed: 19         41
# Unnamed: 20         41
# Unnamed: 21         41
# Unnamed: 22         41
# Unnamed: 23         41
# Unnamed: 24         41
# Unnamed: 25         41
# Unnamed: 26         41
# Unnamed: 27         41
# Unnamed: 28         41
# Unnamed: 29         41
#                   ...
# Unnamed: 16294    1932
# Unnamed: 16295    1932
# Unnamed: 16296    1932
# Unnamed: 16297    1932
# Unnamed: 16298    1932
# Unnamed: 16299    1932
# Unnamed: 16300    1932
# Unnamed: 16301    1932
# Unnamed: 16302    1932
# ...

# %%
#check columns names
migrations.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 16314', 'Unnamed: 16315', 'Unnamed: 16316', 'Unnamed: 16317',
#        'Unnamed: 16318', 'Unnamed: 16319', 'Unnamed: 16320', 'Unnamed: 16321',
#        'Unnamed: 16322', 'Unnamed: 16323'],
#       dtype='object', length=16324)

# %%
#drop NaN columns

#create list of columns to be droped
col_drop = ['Unnamed: ' + str(i) for i in range(242,16324)]
#print(col_drop)

#drop the columns
migrations = migrations.drop(col_drop, axis =1)

migrations.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 232 Unnamed: 233  \
# 0        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 2        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 3        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 4        NaN        NaN        NaN        NaN  ...          NaN          NaN
#
# ...

# %%
#drop top rows, unusefull information

#create list of rows to drop
drop_rows = list(range(13))
#print(drop_rows)

#drop the rows
migrations = migrations.drop(drop_rows, axis = 0)

migrations.head()
# Out:
#    Unnamed: 0   Unnamed: 1                                         Unnamed: 2  \
# 13       Year  Sort\norder  Major area, region, country or area of destina...
# 14        NaN          NaN                                                NaN
# 15       1990      1990001                                              WORLD
# 16       1990      1990002                             More developed regions
# 17       1990      1990003                             Less developed regions
#
#    Unnamed: 3 Unnamed: 4        Unnamed: 5                 Unnamed: 6  \
# 13      Notes       Code  Type of data (a)  Country or area of origin
# 14        NaN        NaN               NaN                      Total
# 15        NaN        900               NaN                152,542,373
# 16          b        901               NaN                 82,391,619
# 17          c        902               NaN                 70,150,754
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  ... Unnamed: 232 Unnamed: 233  \
# ...

# %%
#drop all rows with only NaN values
migra_no_nan = migrations.dropna(how='all')
migra_no_nan.head()
# Out:
#    Unnamed: 0   Unnamed: 1                                         Unnamed: 2  \
# 13       Year  Sort\norder  Major area, region, country or area of destina...
# 14        NaN          NaN                                                NaN
# 15       1990      1990001                                              WORLD
# 16       1990      1990002                             More developed regions
# 17       1990      1990003                             Less developed regions
#
#    Unnamed: 3 Unnamed: 4        Unnamed: 5                 Unnamed: 6  \
# 13      Notes       Code  Type of data (a)  Country or area of origin
# 14        NaN        NaN               NaN                      Total
# 15        NaN        900               NaN                152,542,373
# 16          b        901               NaN                 82,391,619
# 17          c        902               NaN                 70,150,754
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  ... Unnamed: 232 Unnamed: 233  \
# ...

# %%
#migrations.shape
migra_no_nan.shape
# Out:
# (1907, 242)

# %%
migra_no_nan.tail()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1925        NaN        NaN        NaN        NaN        NaN        NaN
# 1926        NaN        NaN        NaN        NaN        NaN        NaN
# 1927        NaN        NaN        NaN        NaN        NaN        NaN
# 1928        NaN        NaN        NaN        NaN        NaN        NaN
# 1931        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 232  \
# 1925        NaN        NaN        NaN        NaN  ...          NaN
# 1926        NaN        NaN        NaN        NaN  ...          NaN
# 1927        NaN        NaN        NaN        NaN  ...          NaN
# 1928        NaN        NaN        NaN        NaN  ...          NaN
# 1931        NaN        NaN        NaN        NaN  ...          NaN
#
#      Unnamed: 233 Unnamed: 234 Unnamed: 235 Unnamed: 236 Unnamed: 237  \
# ...

# %%
#drop unusefull columns
migra_no_nan = migra_no_nan.drop(['Unnamed: 1','Unnamed: 3','Unnamed: 4','Unnamed: 5'], axis = 1)
migra_no_nan.head()
# Out:
#    Unnamed: 0                                         Unnamed: 2  \
# 13       Year  Major area, region, country or area of destina...
# 14        NaN                                                NaN
# 15       1990                                              WORLD
# 16       1990                             More developed regions
# 17       1990                             Less developed regions
#
#                    Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 13  Country or area of origin          NaN          NaN          NaN
# 14                      Total  Other North  Other South  Afghanistan
# 15                152,542,373    2,144,536    6,342,531    6,724,681
# 16                 82,391,619    1,094,823    3,412,144      119,338
# 17                 70,150,754    1,049,713    2,930,387    6,605,343
#
#    Unnamed: 10 Unnamed: 11     Unnamed: 12 Unnamed: 13  ... Unnamed: 232  \
# 13         NaN         NaN             NaN         NaN  ...          NaN
# ...

# %%
#put on headers in the same row and delete row '13'

migra_no_nan.loc[14,'Unnamed: 0'] = 'Year' 
migra_no_nan.loc[14,'Unnamed: 2'] = 'Area/Region/Country' 
migra_no_nan.loc[14,'Unnamed: 6'] = 'Country or Area of Origin / Total' 
migra_no_nan = migra_no_nan.drop(13, axis = 0)

migra_no_nan.head()
# Out:
#    Unnamed: 0                 Unnamed: 2                         Unnamed: 6  \
# 14       Year        Area/Region/Country  Country or Area of Origin / Total
# 15       1990                      WORLD                        152,542,373
# 16       1990     More developed regions                         82,391,619
# 17       1990     Less developed regions                         70,150,754
# 18       1990  Least developed countries                         11,073,226
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 14  Other North  Other South  Afghanistan     Albania     Algeria
# 15    2,144,536    6,342,531    6,724,681     179,490     906,030
# 16    1,094,823    3,412,144      119,338     177,192     851,351
# 17    1,049,713    2,930,387    6,605,343       2,298      54,679
# 18      250,575      533,018           ..          ..       5,587
#
#        Unnamed: 12 Unnamed: 13  ... Unnamed: 232 Unnamed: 233  \
# ...

# %%
migra_no_nan.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13',
#        ...
#        'Unnamed: 232', 'Unnamed: 233', 'Unnamed: 234', 'Unnamed: 235',
#        'Unnamed: 236', 'Unnamed: 237', 'Unnamed: 238', 'Unnamed: 239',
#        'Unnamed: 240', 'Unnamed: 241'],
#       dtype='object', length=238)

# %%
#drop last column
migra_no_nan = migra_no_nan.drop('Unnamed: 241', axis = 1)
migra_no_nan.head()
# Out:
#    Unnamed: 0                 Unnamed: 2                         Unnamed: 6  \
# 14       Year        Area/Region/Country  Country or Area of Origin / Total
# 15       1990                      WORLD                        152,542,373
# 16       1990     More developed regions                         82,391,619
# 17       1990     Less developed regions                         70,150,754
# 18       1990  Least developed countries                         11,073,226
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 14  Other North  Other South  Afghanistan     Albania     Algeria
# 15    2,144,536    6,342,531    6,724,681     179,490     906,030
# 16    1,094,823    3,412,144      119,338     177,192     851,351
# 17    1,049,713    2,930,387    6,605,343       2,298      54,679
# 18      250,575      533,018           ..          ..       5,587
#
#        Unnamed: 12 Unnamed: 13  ... Unnamed: 231 Unnamed: 232 Unnamed: 233  \
# ...

# %%
#redefine header row

new_header = migra_no_nan.iloc[0] #grab the first row for the header
migra_new_header = migra_no_nan[1:] #take the data less the header row
migra_new_header.columns = new_header #set the header row as the df header

migra_new_header.head()
# Out:
# 14  Year                                Area/Region/Country  \
# 15  1990                                              WORLD
# 16  1990                             More developed regions
# 17  1990                             Less developed regions
# 18  1990                          Least developed countries
# 19  1990  Less developed regions, excluding least develo...
#
# 14 Country or Area of Origin / Total Other North Other South Afghanistan  \
# 15                       152,542,373   2,144,536   6,342,531   6,724,681
# 16                        82,391,619   1,094,823   3,412,144     119,338
# 17                        70,150,754   1,049,713   2,930,387   6,605,343
# 18                        11,073,226     250,575     533,018          ..
# 19                        59,077,528     799,138   2,397,369   6,605,343
#
# 14  Albania  Algeria American Samoa Andorra  ...  Uruguay Uzbekistan Vanuatu  \
# 15  179,490  906,030          2,041   3,792  ...  237,258  1,429,956   5,060
# ...

# %%
migra_new_header.tail()
# Out:
# 14   Year Area/Region/Country Country or Area of Origin / Total Other North  \
# 1925  NaN                 NaN                               NaN         NaN
# 1926  NaN                 NaN                               NaN         NaN
# 1927  NaN                 NaN                               NaN         NaN
# 1928  NaN                 NaN                               NaN         NaN
# 1931  NaN                 NaN                               NaN         NaN
#
# 14   Other South Afghanistan Albania Algeria American Samoa Andorra  ...  \
# 1925         NaN         NaN     NaN     NaN            NaN     NaN  ...
# 1926         NaN         NaN     NaN     NaN            NaN     NaN  ...
# 1927         NaN         NaN     NaN     NaN            NaN     NaN  ...
# 1928         NaN         NaN     NaN     NaN            NaN     NaN  ...
# 1931         NaN         NaN     NaN     NaN            NaN     NaN  ...
#
# ...

# %%
#delete NaN rows
migra_NaN_rows = migra_new_header.dropna(axis = 0)
migra_NaN_rows.tail()
# Out:
# 14    Year        Area/Region/Country Country or Area of Origin / Total  \
# 1900  2017                      Samoa                             4,879
# 1901  2017                    Tokelau                               504
# 1902  2017                      Tonga                             4,952
# 1903  2017                     Tuvalu                               143
# 1904  2017  Wallis and Futuna Islands                             2,779
#
# 14   Other North Other South Afghanistan Albania Algeria American Samoa  \
# 1900         109         336          ..      ..      ..          1,571
# 1901           3          37          ..      ..      ..             ..
# 1902       1,918       1,647          ..      ..      ..             ..
# 1903          14          18          ..      ..      ..             ..
# 1904          52          31          ..      ..      ..             ..
#
# 14   Andorra  ... Uruguay Uzbekistan Vanuatu  \
# 1900      ..  ...      ..         ..      16
# ...

# %%
migra_NaN_rows.columns
# Out:
# Index(['Year', 'Area/Region/Country', 'Country or Area of Origin / Total',
#        'Other North', 'Other South', 'Afghanistan', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam',
#        'Wallis and Futuna Islands', 'Western Sahara', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name=14, length=237)

# %%
migra_NaN_rows.head()
# Out:
# 14  Year                                Area/Region/Country  \
# 15  1990                                              WORLD
# 16  1990                             More developed regions
# 17  1990                             Less developed regions
# 18  1990                          Least developed countries
# 19  1990  Less developed regions, excluding least develo...
#
# 14 Country or Area of Origin / Total Other North Other South Afghanistan  \
# 15                       152,542,373   2,144,536   6,342,531   6,724,681
# 16                        82,391,619   1,094,823   3,412,144     119,338
# 17                        70,150,754   1,049,713   2,930,387   6,605,343
# 18                        11,073,226     250,575     533,018          ..
# 19                        59,077,528     799,138   2,397,369   6,605,343
#
# 14  Albania  Algeria American Samoa Andorra  ...  Uruguay Uzbekistan Vanuatu  \
# 15  179,490  906,030          2,041   3,792  ...  237,258  1,429,956   5,060
# ...

# %%
migra_NaN_rows.dtypes
# Out:
# 14
# Year                                  object
# Area/Region/Country                   object
# Country or Area of Origin / Total     object
# Other North                           object
# Other South                           object
# Afghanistan                           object
# Albania                               object
# Algeria                               object
# American Samoa                        object
# Andorra                               object
# Angola                                object
# Anguilla                              object
# Antigua and Barbuda                   object
# Argentina                             object
# Armenia                               object
# Aruba                                 object
# Australia                             object
# Austria                               object
# Azerbaijan                            object
# Bahamas                               object
# Bahrain                               object
# ...

# %%
#reset indexes
migra_index = migra_NaN_rows.reset_index(drop = True)

# %%
migra_index.head()
# Out:
# 14  Year                                Area/Region/Country  \
# 0   1990                                              WORLD
# 1   1990                             More developed regions
# 2   1990                             Less developed regions
# 3   1990                          Least developed countries
# 4   1990  Less developed regions, excluding least develo...
#
# 14 Country or Area of Origin / Total Other North Other South Afghanistan  \
# 0                        152,542,373   2,144,536   6,342,531   6,724,681
# 1                         82,391,619   1,094,823   3,412,144     119,338
# 2                         70,150,754   1,049,713   2,930,387   6,605,343
# 3                         11,073,226     250,575     533,018          ..
# 4                         59,077,528     799,138   2,397,369   6,605,343
#
# 14  Albania  Algeria American Samoa Andorra  ...  Uruguay Uzbekistan Vanuatu  \
# 0   179,490  906,030          2,041   3,792  ...  237,258  1,429,956   5,060
# ...

# %%
#remove commas
migra_comma = migra_index.applymap(lambda x: str(x.replace(',','')))
migra_comma.head()
# Out:
# 14  Year                                Area/Region/Country  \
# 0   1990                                              WORLD
# 1   1990                             More developed regions
# 2   1990                             Less developed regions
# 3   1990                          Least developed countries
# 4   1990  Less developed regions excluding least develop...
#
# 14 Country or Area of Origin / Total Other North Other South Afghanistan  \
# 0                          152542373     2144536     6342531     6724681
# 1                           82391619     1094823     3412144      119338
# 2                           70150754     1049713     2930387     6605343
# 3                           11073226      250575      533018          ..
# 4                           59077528      799138     2397369     6605343
#
# 14 Albania Algeria American Samoa Andorra  ... Uruguay Uzbekistan Vanuatu  \
# 0   179490  906030           2041    3792  ...  237258    1429956    5060
# ...

# %%
#remove commas
migra_comma = migra_comma.applymap(lambda x: str(x.replace('..','0')))
migra_comma.head()
# Out:
# 14  Year                                Area/Region/Country  \
# 0   1990                                              WORLD
# 1   1990                             More developed regions
# 2   1990                             Less developed regions
# 3   1990                          Least developed countries
# 4   1990  Less developed regions excluding least develop...
#
# 14 Country or Area of Origin / Total Other North Other South Afghanistan  \
# 0                          152542373     2144536     6342531     6724681
# 1                           82391619     1094823     3412144      119338
# 2                           70150754     1049713     2930387     6605343
# 3                           11073226      250575      533018           0
# 4                           59077528      799138     2397369     6605343
#
# 14 Albania Algeria American Samoa Andorra  ... Uruguay Uzbekistan Vanuatu  \
# 0   179490  906030           2041    3792  ...  237258    1429956    5060
# ...

# %%
#define data types

#create list of columns
col_list = list(migra_comma.columns)
del col_list[1]
#print(col_list)

for col in col_list:
    migra_comma[col] = migra_comma[col].astype('int64')
    
migra_comma.dtypes
# Out:
# 14
# Year                                   int64
# Area/Region/Country                   object
# Country or Area of Origin / Total      int64
# Other North                            int64
# Other South                            int64
# Afghanistan                            int64
# Albania                                int64
# Algeria                                int64
# American Samoa                         int64
# Andorra                                int64
# Angola                                 int64
# Anguilla                               int64
# Antigua and Barbuda                    int64
# Argentina                              int64
# Armenia                                int64
# Aruba                                  int64
# Australia                              int64
# Austria                                int64
# Azerbaijan                             int64
# Bahamas                                int64
# Bahrain                                int64
# ...

# %%
migra_comma.tail()
# Out:
# 14    Year        Area/Region/Country  Country or Area of Origin / Total  \
# 1885  2017                      Samoa                               4879
# 1886  2017                    Tokelau                                504
# 1887  2017                      Tonga                               4952
# 1888  2017                     Tuvalu                                143
# 1889  2017  Wallis and Futuna Islands                               2779
#
# 14    Other North  Other South  Afghanistan  Albania  Algeria  American Samoa  \
# 1885          109          336            0        0        0            1571
# 1886            3           37            0        0        0               0
# 1887         1918         1647            0        0        0               0
# 1888           14           18            0        0        0               0
# 1889           52           31            0        0        0               0
#
# 14    Andorra  ...  Uruguay  Uzbekistan  Vanuatu  \
# ...

# %%
migra_from_2014 = migra_comma[migra_comma['Year'] >= 2014]
migra_from_2014.head()
# Out:
# 14    Year                                Area/Region/Country  \
# 1350  2015                                              WORLD
# 1351  2015                             More developed regions
# 1352  2015                             Less developed regions
# 1353  2015                          Least developed countries
# 1354  2015  Less developed regions excluding least develop...
#
# 14    Country or Area of Origin / Total  Other North  Other South  \
# 1350                          247585744      3386035      6715476
# 1351                          140250197       734208      2715149
# 1352                          107335547      2651827      4000327
# 1353                           13804757       438594       965867
# 1354                           93530790      2213233      3034460
#
# 14    Afghanistan  Albania  Algeria  American Samoa  Andorra  ...  Uruguay  \
# 1350      4855376  1137917  1785555            2035     7589  ...   348569
# ...

# %%
migra_from_2014.tail()
# Out:
# 14    Year        Area/Region/Country  Country or Area of Origin / Total  \
# 1885  2017                      Samoa                               4879
# 1886  2017                    Tokelau                                504
# 1887  2017                      Tonga                               4952
# 1888  2017                     Tuvalu                                143
# 1889  2017  Wallis and Futuna Islands                               2779
#
# 14    Other North  Other South  Afghanistan  Albania  Algeria  American Samoa  \
# 1885          109          336            0        0        0            1571
# 1886            3           37            0        0        0               0
# 1887         1918         1647            0        0        0               0
# 1888           14           18            0        0        0               0
# 1889           52           31            0        0        0               0
#
# 14    Andorra  ...  Uruguay  Uzbekistan  Vanuatu  \
# ...

# %%
migra_from_2014.to_csv('migration_2014.csv')

# %%
migra_from_2014_1 = migra_from_2014[['Year','Area/Region/Country','Country or Area of Origin / Total']]
migra_from_2014_1.head()
# Out:
# 14    Year                                Area/Region/Country  \
# 1350  2015                                              WORLD
# 1351  2015                             More developed regions
# 1352  2015                             Less developed regions
# 1353  2015                          Least developed countries
# 1354  2015  Less developed regions excluding least develop...
#
# 14    Country or Area of Origin / Total
# 1350                          247585744
# 1351                          140250197
# 1352                          107335547
# 1353                           13804757
# 1354                           93530790

# %%
migra_from_2014_1.to_csv('migration_2014_totals.csv')
