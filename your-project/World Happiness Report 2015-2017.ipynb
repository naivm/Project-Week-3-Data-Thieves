# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # World Happiness Report 2015

# %%
whr_2015_input = pd.read_csv("whr_2015.csv")
whr_2015_input.set_index("Happiness Rank")
# Out:
#                     Country                           Region  Happiness Score  \
# Happiness Rank
# 1               Switzerland                   Western Europe            7.587
# 2                   Iceland                   Western Europe            7.561
# 3                   Denmark                   Western Europe            7.527
# 4                    Norway                   Western Europe            7.522
# 5                    Canada                    North America            7.427
# ...                     ...                              ...              ...
# 154                  Rwanda               Sub-Saharan Africa            3.465
# 155                   Benin               Sub-Saharan Africa            3.340
# 156                   Syria  Middle East and Northern Africa            3.006
# 157                 Burundi               Sub-Saharan Africa            2.905
# 158                    Togo               Sub-Saharan Africa            2.839
#
# ...

# %%
whr_2015 = whr_2015_input[["Happiness Rank","Country","Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Generosity","Trust (Government Corruption)","Dystopia Residual"]]
whr_2015.set_index("Happiness Rank")
# Out:
#                     Country  Happiness Score  Economy (GDP per Capita)  \
# Happiness Rank
# 1               Switzerland            7.587                   1.39651
# 2                   Iceland            7.561                   1.30232
# 3                   Denmark            7.527                   1.32548
# 4                    Norway            7.522                   1.45900
# 5                    Canada            7.427                   1.32629
# ...                     ...              ...                       ...
# 154                  Rwanda            3.465                   0.22208
# 155                   Benin            3.340                   0.28665
# 156                   Syria            3.006                   0.66320
# 157                 Burundi            2.905                   0.01530
# 158                    Togo            2.839                   0.20868
#
#                  Family  Health (Life Expectancy)  Freedom  Generosity  \
# Happiness Rank
# ...

# %% [markdown]
# # Relation BIP to total Happiness Score

# %%
whr_2015_input["relation_BIP"] = whr_2015.loc[:,("Economy (GDP per Capita)")]/whr_2015.loc[:,("Happiness Score")]*100
whr_2015_input
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
sort_BIP= whr_2015_input.sort_values(by = "relation_BIP", ascending=False)
sort_BIP
# Out:
#               Country                           Region  Happiness Rank  \
# 142             Gabon               Sub-Saharan Africa             143
# 27              Qatar  Middle East and Northern Africa              28
# 71          Hong Kong                     Eastern Asia              72
# 38             Kuwait  Middle East and Northern Africa              39
# 133          Bulgaria       Central and Eastern Europe             134
# ..                ...                              ...             ...
# 93         Mozambique               Sub-Saharan Africa              94
# 115           Liberia               Sub-Saharan Africa             116
# 156           Burundi               Sub-Saharan Africa             157
# 130            Malawi               Sub-Saharan Africa             131
# 119  Congo (Kinshasa)               Sub-Saharan Africa             120
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %% [markdown]
# # World Happiness Report 2016

# %%
whr_2016_input = pd.read_csv("whr_2016.csv")

# %%
whr_2016 = whr_2016_input[["Happiness Rank","Country","Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Generosity","Trust (Government Corruption)","Dystopia Residual"]]
whr_2016.set_index("Happiness Rank")
# Out:
#                     Country  Happiness Score  Economy (GDP per Capita)  \
# Happiness Rank
# 1                   Denmark            7.526                   1.44178
# 2               Switzerland            7.509                   1.52733
# 3                   Iceland            7.501                   1.42666
# 4                    Norway            7.498                   1.57744
# 5                   Finland            7.413                   1.40598
# ...                     ...              ...                       ...
# 153                   Benin            3.484                   0.39499
# 154             Afghanistan            3.360                   0.38227
# 155                    Togo            3.303                   0.28123
# 156                   Syria            3.069                   0.74719
# 157                 Burundi            2.905                   0.06831
#
#                  Family  Health (Life Expectancy)  Freedom  Generosity  \
# Happiness Rank
# ...

# %% [markdown]
# # World Happiness Report 2017

# %%
whr_2017_input = pd.read_csv("whr_2017.csv")

# %%
whr_2017_input.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
whr_2017_input = whr_2017_input.rename(columns={'Happiness.Rank': 'Happiness Rank' , 'Happiness.Score':'Happiness Score', 'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)', 'Health..Life.Expectancy.':'Health (Life Expectancy)',
       'Trust..Government.Corruption.': 'Trust (Government Corruption)', 'Dystopia.Residual': 'Dystopia Residual'})

# %%
whr_2017 = whr_2017_input[["Happiness Rank","Country","Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Generosity","Trust (Government Corruption)","Dystopia Residual"]]

# %%
whr_2017.set_index("Happiness Rank")
# Out:
#                                  Country  Happiness Score  \
# Happiness Rank
# 1                                 Norway            7.537
# 2                                Denmark            7.522
# 3                                Iceland            7.504
# 4                            Switzerland            7.494
# 5                                Finland            7.469
# ...                                  ...              ...
# 151                               Rwanda            3.471
# 152                                Syria            3.462
# 153                             Tanzania            3.349
# 154                              Burundi            2.905
# 155             Central African Republic            2.693
#
#                 Economy (GDP per Capita)    Family  Health (Life Expectancy)  \
# Happiness Rank
# 1                               1.616463  1.533524                  0.796667
# 2                               1.482383  1.551122                  0.792566
# ...

# %% [markdown]
# # Top 5 and least 5 of 2017

# %%
whr_Topbottom = whr_2017.iloc[np.r_[0:5, -5:0]]
whr_Topbottom
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                    Norway            7.537
# 1                 2                   Denmark            7.522
# 2                 3                   Iceland            7.504
# 3                 4               Switzerland            7.494
# 4                 5                   Finland            7.469
# 150             151                    Rwanda            3.471
# 151             152                     Syria            3.462
# 152             153                  Tanzania            3.349
# 153             154                   Burundi            2.905
# 154             155  Central African Republic            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# 1                    1.482383  1.551122                  0.792566  0.626007
# ...

# %% [markdown]
# # Create List for Gini-Index

# %%
country_names= whr_2017["Country"]
print(list(country_names))
# Out:
# ['Norway', 'Denmark', 'Iceland', 'Switzerland', 'Finland', 'Netherlands', 'Canada', 'New Zealand', 'Sweden', 'Australia', 'Israel', 'Costa Rica', 'Austria', 'United States', 'Ireland', 'Germany', 'Belgium', 'Luxembourg', 'United Kingdom', 'Chile', 'United Arab Emirates', 'Brazil', 'Czech Republic', 'Argentina', 'Mexico', 'Singapore', 'Malta', 'Uruguay', 'Guatemala', 'Panama', 'France', 'Thailand', 'Taiwan Province of China', 'Spain', 'Qatar', 'Colombia', 'Saudi Arabia', 'Trinidad and Tobago', 'Kuwait', 'Slovakia', 'Bahrain', 'Malaysia', 'Nicaragua', 'Ecuador', 'El Salvador', 'Poland', 'Uzbekistan', 'Italy', 'Russia', 'Belize', 'Japan', 'Lithuania', 'Algeria', 'Latvia', 'South Korea', 'Moldova', 'Romania', 'Bolivia', 'Turkmenistan', 'Kazakhstan', 'North Cyprus', 'Slovenia', 'Peru', 'Mauritius', 'Cyprus', 'Estonia', 'Belarus', 'Libya', 'Turkey', 'Paraguay', 'Hong Kong S.A.R., China', 'Philippines', 'Serbia', 'Jordan', 'Hungary', 'Jamaica', 'Croatia', 'Kosovo', 'China', 'Pakistan', 'Ind
# ...

# %% [markdown]
# # Comparison of Score Years 2015-2017

# %%
# Merge year 2015 and 2016 by Country
comparison15_16 = pd.merge(whr_2015_input, whr_2016_input, on="Country")

# Merge year 2015+2016 and 2017 by Country
comparison15_16_17 = pd.merge(comparison15_16, whr_2017_input, on = "Country")
whr_2017_input = comparison15_16_17.rename(columns={"Happiness Score_x": "Happiness Score 2015","Happiness Score_y": "Happiness Score 2016","Happiness Score":"Happiness Score 2017"})

# %%
# Merge year 2015+2016 and 2017 by Country
comparison15_16_17 = pd.merge(comparison15_16, whr_2017_input, on = "Country")
whr_2017_input = comparison15_16_17.rename(columns={"Happiness Score_x": "Happiness Score 2015","Happiness Score_y": "Happiness Score 2016","Happiness Score":"Happiness Score 2017"})

# %%
compare_yearly = comparison15_16_17[["Country","Happiness Score 2015","Happiness Score 2016","Happiness Score 2017"]]
compare_yearly.head()
# Out:
#        Country  Happiness Score 2015  Happiness Score 2016  \
# 0  Switzerland                 7.587                 7.509
# 1      Iceland                 7.561                 7.501
# 2      Denmark                 7.527                 7.526
# 3       Norway                 7.522                 7.498
# 4       Canada                 7.427                 7.404
#
#    Happiness Score 2017
# 0                 7.494
# 1                 7.504
# 2                 7.522
# 3                 7.537
# 4                 7.316

# %%
#compare_yearly["Difference"]=
Difference = list(compare_yearly["Happiness Score 2017"]-compare_yearly["Happiness Score 2015"])
Difference
# Out:
# [-0.09300004196167055,
#  -0.056999813079830375,
#  -0.005000164031979892,
#  0.015000179290768578,
#  -0.11100001525879044,
#  0.06299986267090052,
#  -0.001000144958498872,
#  -0.08000008010863979,
#  0.02800012969970922,
#  -8.01086397217432e-08,
#  -0.0650001792907684,
#  -0.1470000038146999,
#  -0.19399995803833026,
#  -0.6089999313354504,
#  -0.12599996948241898,
#  -0.34799977111816016,
#  -0.08300008392334046,
#  0.03700023651123008,
#  -0.046000205993649956,
#  -0.25300023651123027,
#  -0.15299977493286132,
#  -1.5599999999999996,
#  -0.22599997329711918,
#  -0.33399985885620076,
#  0.20100021362304954,
#  -0.01800004959105994,
#  -0.23600000000000065,
#  -0.13300008773803995,
#  0.024999977111820115,
#  0.10400020599364979,
#  -0.03100000381470025,
#  -0.12000012588501008,
#  -0.03100021362304961,
#  -0.06700013732909937,
#  0.07399987792969043,
#  0.2249999504089395,
#  -0.18999998092651005,
#  2.2125244125703603e-07,
#  -0.12700021743774048,
#  0.33099999618530074,
# ...

# %%
compare_yearly_diff = compare_yearly.assign(Difference= list(compare_yearly["Happiness Score 2017"]-compare_yearly["Happiness Score 2015"]))
compare_yearly_diff.head()#.sort_values(by = "Difference", ascending= False)
# Out:
#        Country  Happiness Score 2015  Happiness Score 2016  \
# 0  Switzerland                 7.587                 7.509
# 1      Iceland                 7.561                 7.501
# 2      Denmark                 7.527                 7.526
# 3       Norway                 7.522                 7.498
# 4       Canada                 7.427                 7.404
#
#    Happiness Score 2017  Difference
# 0                 7.494      -0.093
# 1                 7.504      -0.057
# 2                 7.522      -0.005
# 3                 7.537       0.015
# 4                 7.316      -0.111
